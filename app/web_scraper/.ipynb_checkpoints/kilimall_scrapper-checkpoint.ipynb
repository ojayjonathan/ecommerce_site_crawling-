# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import math

# %%
driver = webdriver.Chrome('/home/ojay/chromedriver_linux64/chromedriver')

# %%
driver.get('https://www.kilimall.co.ke/new/commoditysearch?q=men+watch')
p= driver.page_source

# %%
soup = BeautifulSoup(p, 'lxml')

# %%
soup.body.find(class_='results').text.split(' ')[1]
# Out:
# '3994'

# %%
price_ele = ele_result[0].find(class_='wordwrap-price')
soup.title

# %%
def jsonProductSerializer(name,item_link, image_path, price, prev_price, item_reviews,rating, per_discount):
    return{"product_name":name, "item_link":item_link, "image_src":image_path, "price":price, 
           "prev_price":prev_price, "item_review":item_reviews, "rating":rating, 'per_discount':per_discount}

class KilimalSeleniumScrapper():
    def __init__(self):
        #search_parameters => dict object (q,page_number,filters,*kwargs)
        #jumia search url 
        self.url = 'https://www.kilimall.co.ke/new/commoditysearch?'
        self.items_found = 0
        self.pages_found = 0
        self.driver = webdriver.Chrome('/home/ojay/chromedriver_linux64/chromedriver')
    def call(self,filter_parameters,page_number='page_1'):
        data= list()
        parameters='&'.join(['{}={}'.format(key,filter_parameters[key]) for key in filter_parameters.keys()])
        print(self.url+parameters)
        self.driver.get(self.url+parameters)
        html_string = self.driver.page_source
        soup= BeautifulSoup(html_string, 'lxml')
        title = soup.title.text
        ele_result= soup.body.find_all(class_="el-col el-col-6") 
        for i, article in enumerate(ele_result):
            item_link,prev_price, product_name, review, image_path,rating,price, per_discount =None, None, None, None, None, None, None, None
            try:
                price_ele = article.find(class_='wordwrap-price')
                price = price_ele.find('span').text
                prev_price =  price_ele.find(class_='twoksh').text
                item_link = ('https://www.kilimall.co.ke/{}').format(article.a['href'])
                product_name = article.find(class_='wordwrap').text
                image_path=article.img['src']
                per_discount = article.find(class_='greenbox').text
                review = article.find(class_='sixtwo').text 
                if page_number=='page_1':
                    self.result_found = soup.body.find(class_='results').text.split(' ')[1]
                    pages_found = soup.body.find(class_='leftpaging').text.split('/')[-1]
                    self.pages_found = int(pages_found)
            except:
                pass
            item_data = jsonProductSerializer(name=product_name,item_link=item_link, 
                                          image_path=image_path, price=price, 
                                          prev_price=prev_price, item_reviews=review,rating=rating, per_discount=per_discount)
            data.append(item_data) 
        return title, [{page_number:data}]
    def get_result(self, filter_parameters, max_number_pages=5):
        title,query_result, num_pages = self.call(filter_parameters)
        for i in range(2,max_number_pages+1):
            if i<=self.pages_found:
                filter_parameters['page']=i
                _, page_data = self.call(filter_parameters,page_number='page_{}'.format(i))
                query_result.append(page_data[0])
        self.driver.quit()        
        return {'title':title,'items_found':self.result_found,'data':query_result}

# %%
kilimal = KilimalSeleniumScrapper()
result = kilimal.get_result({'q':'men+watches'},max_number_pages=3)
# Out:
# https://www.kilimall.co.ke/new/commoditysearch?q=men+watches
# items 40
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# 101  4008
# https://www.kilimall.co.ke/new/commoditysearch?q=men+watches&page=2
# items 40
# https://www.kilimall.co.ke/new/commoditysearch?q=men+watches&page=3
# items 40

# %%
result
# Out:
# {'title': 'Best price men watches online shopping on Kilimall',
#  'data': [{'page_1': [{'product_name': 'CUENA Men Watch leather straps Stainless Steel Good Quartz Luxury Man Wristwatch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/12/3281_06295448209529386_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(1151)',
#      'rating': None,
#      'per_discount': '90% Off'},
#     {'product_name': 'Men Watch Date Stainless Steel Male Watches Quartz WristWatch Wrist Watch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/08/3281_06198784598670487_240.jpg',
#      'price': 'KSh 690',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(268)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Men Watch Stainless Quartz WristWatch Waterproof Lady Lovers Women Male Date Classic Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/08/3281_06198840873745713_240.jpg',
#      'price': 'KSh 699',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(249)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Genuine Curren Men Watches Fashion Sports Quartz Watches Leather Military Watch Gifts black 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440828496201102_240.jpg',
#      'price': 'KSh 450',
#      'prev_price': 'KSh 1,500',
#      'item_review': '(628)',
#      'rating': None,
#      'per_discount': '70% Off'},
#     {'product_name': "Men's Watch Quartz Men's Watch Blu-ray Glass Belt Watch Men's Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/04/5057_06099858887919745_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(296)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Genuine Men Watches Dial Military Quartz Leather Sport Watches Male Business Wristwatch black 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440830518573343_240.jpg',
#      'price': 'KSh 440',
#      'prev_price': 'KSh 1,599',
#      'item_review': '(469)',
#      'rating': None,
#      'per_discount': '72% Off'},
#     {'product_name': 'Yazole Leather Men Watch Man Luxury Quartz Stainless Steel Wrist Watches Wristwatch Valentine Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/11/3281_06275935451037089_240.png',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(186)',
#      'rating': None,
#      'per_discount': '86% Off'},
#     {'product_name': 'SKMEI Men Watches Sport Electronics Digital LED Quartz Watches Waterproof Alarm Watches Gifts black 25CM',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440740584138671_240.jpg',
#      'price': 'KSh 990',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(448)',
#      'rating': None,
#      'per_discount': '67% Off'},
#     {'product_name': 'Genuine Migeer Men Watches Leather Straps Stainless Steel Quartz Man Wristwatch Gifts brown 22cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/06/1213_06443213195115322_240.jpg',
#      'price': 'KSh 449',
#      'prev_price': 'KSh 1,500',
#      'item_review': '(529)',
#      'rating': None,
#      'per_discount': '70% Off'},
#     {'product_name': 'Luxury Men Watch Fashion Diamond Automatic Date Quartz Watch Men Gold Stainless Steel Hip Hop Watche',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06353739341067779_240.jpg',
#      'price': 'KSh 899',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(54)',
#      'rating': None,
#      'per_discount': '55% Off'},
#     {'product_name': 'Men Watches Fashion Casual Quartz Watch Geneva Fabric Nylon Canvas Military Watches Gifts 2 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/06/1213_06443213946897453_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(443)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Men Watches Stainless Steel Lady Watch Lovers Luxury Quartz Good Wristwatches Man Male Gift Women',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/07/3281_06174571743026090_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(122)',
#      'rating': None,
#      'per_discount': '86% Off'},
#     {'product_name': 'BOSCK Brand Original Mens Watch Stainless Steel Waterproof Men Quartz Watch Men Watch for Men Black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2018/03/2247_05754005615764969_240.jpg',
#      'price': 'KSh 599',
#      'prev_price': 'KSh 2,560',
#      'item_review': '(347)',
#      'rating': None,
#      'per_discount': '76% Off'},
#     {'product_name': '2020men watches Men Business Wristwatch Luxury Famous Male Clock Sports Quartz Watch Valentines Gift white brown one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/01/2223_05693730498201533_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 1,100',
#      'item_review': '(444)',
#      'rating': None,
#      'per_discount': '63% Off'},
#     {'product_name': 'Mens Watches Luxury Men Fashion Business Quartz watch clock Male WristWatches Valentines Gift black black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/02/2223_05731245282486211_240.jpg',
#      'price': 'KSh 369',
#      'prev_price': 'KSh 850',
#      'item_review': '(576)',
#      'rating': None,
#      'per_discount': '56% Off'},
#     {'product_name': "STSR New fashion watch men's watch luxury top brand casual sports quartz watch male clock",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5750/2019/09/5750_06229849127026454_240.jpg',
#      'price': 'KSh 179',
#      'prev_price': 'KSh 2,000',
#      'item_review': '(125)',
#      'rating': None,
#      'per_discount': '91% Off'},
#     {'product_name': "Fashion Gift Watch Quartz Watch Men's Colorful Blu-ray Glass Belt Men's Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5742/2019/11/5742_06261941948722181_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 999',
#      'item_review': '(59)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': '2Pcs/Set Couple Watches Fashion Watches Men Watches Women Watches Fashion Accessories',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1482/2019/08/1482_06184431016347067_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 2,099',
#      'item_review': '(68)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Men Watch leather strap Stainless Steel Good Quartz Luxury Business Man Wristwatch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2555/2019/08/2555_06203492826084739_240.png',
#      'price': 'KSh 429',
#      'prev_price': 'KSh 3,980',
#      'item_review': '(253)',
#      'rating': None,
#      'per_discount': '89% Off'},
#     {'product_name': 'Watch Men Top Brand Luxury Famous 2018 Wristwatch Male Clock Wrist Watch Business Quartz watch black black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/03/2223_05742094787046585_240.jpg',
#      'price': 'KSh 369',
#      'prev_price': 'KSh 1,200',
#      'item_review': '(226)',
#      'rating': None,
#      'per_discount': '69% Off'},
#     {'product_name': "Men's Watch New ORLANDO Fashion Quartz Watch Men's Gold Plated Stainless Steel Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/07/5057_06153000410469662_240.jpg',
#      'price': 'KSh 479',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(187)',
#      'rating': None,
#      'per_discount': '84% Off'},
#     {'product_name': "Fashion trend casual sports business men's watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5742/2020/06/5742_06443445122225261_240.jpg',
#      'price': 'KSh 239',
#      'prev_price': 'KSh 1,298',
#      'item_review': '(50)',
#      'rating': None,
#      'per_discount': '81% Off'},
#     {'product_name': 'SKMEI Men Watches Sports Electronic Military Stainless Steel PU Strap Watches Double Clock Gifts black 25cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440742361245664_240.jpg',
#      'price': 'KSh 1,199',
#      'prev_price': 'KSh 2,500',
#      'item_review': '(178)',
#      'rating': None,
#      'per_discount': '52% Off'},
#     {'product_name': "STSR 2020 Men's High Quality Quartz Luxury Men's Watch Gift Fashion Sports Leather Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/10/5057_06254094190174553_240.jpg',
#      'price': 'KSh 179',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(104)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Hip Hop Men Bracelets Gold Iced Out Crystal Miami Cuban Chain watch +Bracelet set Hip Hop King New',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2019/12/4807_06301869670278671_240.jpg',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 2,699',
#      'item_review': '(74)',
#      'rating': None,
#      'per_discount': '44% Off'},
#     {'product_name': 'NAVIFORCE Fashion Gold Men Sport Watch Mens LED Analog Digital Army Military Leather Quartz Watches',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2218/2019/09/2218_06215369650570981_240.jpg',
#      'price': 'KSh 1,999',
#      'prev_price': 'KSh 3,999',
#      'item_review': '(51)',
#      'rating': None,
#      'per_discount': '50% Off'},
#     {'product_name': 'BOSCK Brand Original Men Business Watch Double Calendar Waterproof Men Quartz Watch Men Watch black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2018/01/2247_05689906772579379_240.jpg',
#      'price': 'KSh 799',
#      'prev_price': 'KSh 3,520',
#      'item_review': '(84)',
#      'rating': None,
#      'per_discount': '77% Off'},
#     {'product_name': 'LSVTR Brand 2 PCS Set Couples Wrist Watches Men Women Lovers Waterproof Quartz Wristwatches silver 2pcs (1 male and 1 female)',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2555/2019/05/2555_06105385890905644_240.png',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 3,999',
#      'item_review': '(170)',
#      'rating': None,
#      'per_discount': '62% Off'},
#     {'product_name': "SWAVES Men's sports electronic waterproof watch with alarm,liesure, mount climbing funchion",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5798/2019/12/5798_06287022389327105_240.jpg',
#      'price': 'KSh 1,388',
#      'prev_price': 'KSh 2,338',
#      'item_review': '(17)',
#      'rating': None,
#      'per_discount': '40% Off'},
#     {'product_name': "Mens Fashion Casual Military Quartz Sports Wristwatch Full Steel  Men's Watches",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/6097/2020/06/6097_06461829899978972_240.jpg',
#      'price': 'KSh 595',
#      'prev_price': 'KSh 1,600',
#      'item_review': '(26)',
#      'rating': None,
#      'per_discount': '62% Off'},
#     {'product_name': '2Pcs/Set Couple Watches Fashion Watches Men Watches Women Watches Fashion Accessories',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1482/2019/08/1482_06184430296665199_240.jpg',
#      'price': 'KSh 459',
#      'prev_price': 'KSh 2,199',
#      'item_review': '(96)',
#      'rating': None,
#      'per_discount': '79% Off'},
#     {'product_name': 'Men Bling Bracelets+Luxury Full Diamonds Watch  Cuban Chain Gold Silver Men watch +Bracelet set',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2019/12/4807_06302371457188196_240.jpg',
#      'price': 'KSh 1,299',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(35)',
#      'rating': None,
#      'per_discount': '35% Off'},
#     {'product_name': 'CURREN 8301 Top Brand Luxury watch men date display Leather creative Quartz Wrist Watches brown one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2218/2018/11/2218_05966805045852660_240.jpg',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 3,200',
#      'item_review': '(149)',
#      'rating': None,
#      'per_discount': '53% Off'},
#     {'product_name': 'JC 2020 LED sports men women smartwatches LED bracelet fashion touch electronic gift watch',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5872/2020/04/5872_06391041963363483_240.jpg',
#      'price': 'KSh 186',
#      'prev_price': 'KSh 555',
#      'item_review': '(18)',
#      'rating': None,
#      'per_discount': '66% Off'},
#     {'product_name': "STSR Men's Stainless Steel Watch Men's Quartz Clock Men's Sports Watch Fashion Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5750/2019/09/5750_06229862591943796_240.jpg',
#      'price': 'KSh 479',
#      'prev_price': 'KSh 2,000',
#      'item_review': '(53)',
#      'rating': None,
#      'per_discount': '76% Off'},
#     {'product_name': 'WLISTH Brand Original Fashion Quartz Watch Alloy Double Calendar Waterproof Men Women Watch Brown Women',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2020/02/2247_06344769268233896_240.jpg',
#      'price': 'KSh 799',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(86)',
#      'rating': None,
#      'per_discount': '60% Off'},
#     {'product_name': "2020 Minimalist Men's Fashion Ultra Thin Watches Simple Men Business Stainless Steel Mesh Belt Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5422/2020/04/5422_06409694646778921_240.jpg',
#      'price': 'KSh 654',
#      'prev_price': 'KSh 2,099',
#      'item_review': '(19)',
#      'rating': None,
#      'per_discount': '68% Off'},
#     {'product_name': 'Men Hip Hop Gold Silver Luxury Bling  Full CZ Crystal Watch Cuba Sandblast Bracelet  Set',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06358130793297137_240.jpg',
#      'price': 'KSh 699',
#      'prev_price': 'KSh 1,699',
#      'item_review': '(15)',
#      'rating': None,
#      'per_discount': '58% Off'},
#     {'product_name': 'Men Women Couple Wrist Watch (not a pair) bracelet PU Leather Strap Round Dial Quartz Wristwatches',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5872/2020/01/5872_06322674366695011_240.jpg',
#      'price': 'KSh 198',
#      'prev_price': 'KSh 699',
#      'item_review': '(25)',
#      'rating': None,
#      'per_discount': '71% Off'},
#     {'product_name': 'Luxury Men Diamond Watch+Diamond Bracelet Luxury Fashion Gold Silver Men Ice Out Cuban Watch',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06359808533248554_240.jpg',
#      'price': 'KSh 1,299',
#      'prev_price': 'KSh 2,499',
#      'item_review': '(27)',
#      'rating': None,
#      'per_discount': '48% Off'}]},
#   {'page_2': [{'product_name': 'CUENA Men Watch leather straps Stainless Steel Good Quartz Luxury Man Wristwatch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/12/3281_06295448209529386_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(1151)',
#      'rating': None,
#      'per_discount': '90% Off'},
#     {'product_name': 'Men Watch Date Stainless Steel Male Watches Quartz WristWatch Wrist Watch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/08/3281_06198784598670487_240.jpg',
#      'price': 'KSh 690',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(268)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Men Watch Stainless Quartz WristWatch Waterproof Lady Lovers Women Male Date Classic Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/08/3281_06198840873745713_240.jpg',
#      'price': 'KSh 699',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(249)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Genuine Curren Men Watches Fashion Sports Quartz Watches Leather Military Watch Gifts black 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440828496201102_240.jpg',
#      'price': 'KSh 450',
#      'prev_price': 'KSh 1,500',
#      'item_review': '(628)',
#      'rating': None,
#      'per_discount': '70% Off'},
#     {'product_name': "Men's Watch Quartz Men's Watch Blu-ray Glass Belt Watch Men's Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/04/5057_06099858887919745_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(296)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Genuine Men Watches Dial Military Quartz Leather Sport Watches Male Business Wristwatch black 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440830518573343_240.jpg',
#      'price': 'KSh 440',
#      'prev_price': 'KSh 1,599',
#      'item_review': '(469)',
#      'rating': None,
#      'per_discount': '72% Off'},
#     {'product_name': 'Yazole Leather Men Watch Man Luxury Quartz Stainless Steel Wrist Watches Wristwatch Valentine Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/11/3281_06275935451037089_240.png',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(186)',
#      'rating': None,
#      'per_discount': '86% Off'},
#     {'product_name': 'SKMEI Men Watches Sport Electronics Digital LED Quartz Watches Waterproof Alarm Watches Gifts black 25CM',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440740584138671_240.jpg',
#      'price': 'KSh 990',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(448)',
#      'rating': None,
#      'per_discount': '67% Off'},
#     {'product_name': 'Genuine Migeer Men Watches Leather Straps Stainless Steel Quartz Man Wristwatch Gifts brown 22cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/06/1213_06443213195115322_240.jpg',
#      'price': 'KSh 449',
#      'prev_price': 'KSh 1,500',
#      'item_review': '(529)',
#      'rating': None,
#      'per_discount': '70% Off'},
#     {'product_name': 'Luxury Men Watch Fashion Diamond Automatic Date Quartz Watch Men Gold Stainless Steel Hip Hop Watche',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06353739341067779_240.jpg',
#      'price': 'KSh 899',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(54)',
#      'rating': None,
#      'per_discount': '55% Off'},
#     {'product_name': 'Men Watches Fashion Casual Quartz Watch Geneva Fabric Nylon Canvas Military Watches Gifts 2 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/06/1213_06443213946897453_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(443)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Men Watches Stainless Steel Lady Watch Lovers Luxury Quartz Good Wristwatches Man Male Gift Women',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/07/3281_06174571743026090_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(122)',
#      'rating': None,
#      'per_discount': '86% Off'},
#     {'product_name': 'BOSCK Brand Original Mens Watch Stainless Steel Waterproof Men Quartz Watch Men Watch for Men Black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2018/03/2247_05754005615764969_240.jpg',
#      'price': 'KSh 599',
#      'prev_price': 'KSh 2,560',
#      'item_review': '(347)',
#      'rating': None,
#      'per_discount': '76% Off'},
#     {'product_name': '2020men watches Men Business Wristwatch Luxury Famous Male Clock Sports Quartz Watch Valentines Gift white brown one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/01/2223_05693730498201533_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 1,100',
#      'item_review': '(444)',
#      'rating': None,
#      'per_discount': '63% Off'},
#     {'product_name': 'Mens Watches Luxury Men Fashion Business Quartz watch clock Male WristWatches Valentines Gift black black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/02/2223_05731245282486211_240.jpg',
#      'price': 'KSh 369',
#      'prev_price': 'KSh 850',
#      'item_review': '(576)',
#      'rating': None,
#      'per_discount': '56% Off'},
#     {'product_name': "STSR New fashion watch men's watch luxury top brand casual sports quartz watch male clock",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5750/2019/09/5750_06229849127026454_240.jpg',
#      'price': 'KSh 179',
#      'prev_price': 'KSh 2,000',
#      'item_review': '(125)',
#      'rating': None,
#      'per_discount': '91% Off'},
#     {'product_name': "Fashion Gift Watch Quartz Watch Men's Colorful Blu-ray Glass Belt Men's Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5742/2019/11/5742_06261941948722181_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 999',
#      'item_review': '(59)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': '2Pcs/Set Couple Watches Fashion Watches Men Watches Women Watches Fashion Accessories',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1482/2019/08/1482_06184431016347067_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 2,099',
#      'item_review': '(68)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Men Watch leather strap Stainless Steel Good Quartz Luxury Business Man Wristwatch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2555/2019/08/2555_06203492826084739_240.png',
#      'price': 'KSh 429',
#      'prev_price': 'KSh 3,980',
#      'item_review': '(253)',
#      'rating': None,
#      'per_discount': '89% Off'},
#     {'product_name': 'Watch Men Top Brand Luxury Famous 2018 Wristwatch Male Clock Wrist Watch Business Quartz watch black black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/03/2223_05742094787046585_240.jpg',
#      'price': 'KSh 369',
#      'prev_price': 'KSh 1,200',
#      'item_review': '(226)',
#      'rating': None,
#      'per_discount': '69% Off'},
#     {'product_name': "Men's Watch New ORLANDO Fashion Quartz Watch Men's Gold Plated Stainless Steel Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/07/5057_06153000410469662_240.jpg',
#      'price': 'KSh 479',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(187)',
#      'rating': None,
#      'per_discount': '84% Off'},
#     {'product_name': "Fashion trend casual sports business men's watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5742/2020/06/5742_06443445122225261_240.jpg',
#      'price': 'KSh 239',
#      'prev_price': 'KSh 1,298',
#      'item_review': '(50)',
#      'rating': None,
#      'per_discount': '81% Off'},
#     {'product_name': 'SKMEI Men Watches Sports Electronic Military Stainless Steel PU Strap Watches Double Clock Gifts black 25cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440742361245664_240.jpg',
#      'price': 'KSh 1,199',
#      'prev_price': 'KSh 2,500',
#      'item_review': '(178)',
#      'rating': None,
#      'per_discount': '52% Off'},
#     {'product_name': "STSR 2020 Men's High Quality Quartz Luxury Men's Watch Gift Fashion Sports Leather Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/10/5057_06254094190174553_240.jpg',
#      'price': 'KSh 179',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(104)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Hip Hop Men Bracelets Gold Iced Out Crystal Miami Cuban Chain watch +Bracelet set Hip Hop King New',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2019/12/4807_06301869670278671_240.jpg',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 2,699',
#      'item_review': '(74)',
#      'rating': None,
#      'per_discount': '44% Off'},
#     {'product_name': 'NAVIFORCE Fashion Gold Men Sport Watch Mens LED Analog Digital Army Military Leather Quartz Watches',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2218/2019/09/2218_06215369650570981_240.jpg',
#      'price': 'KSh 1,999',
#      'prev_price': 'KSh 3,999',
#      'item_review': '(51)',
#      'rating': None,
#      'per_discount': '50% Off'},
#     {'product_name': 'BOSCK Brand Original Men Business Watch Double Calendar Waterproof Men Quartz Watch Men Watch black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2018/01/2247_05689906772579379_240.jpg',
#      'price': 'KSh 799',
#      'prev_price': 'KSh 3,520',
#      'item_review': '(84)',
#      'rating': None,
#      'per_discount': '77% Off'},
#     {'product_name': 'LSVTR Brand 2 PCS Set Couples Wrist Watches Men Women Lovers Waterproof Quartz Wristwatches silver 2pcs (1 male and 1 female)',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2555/2019/05/2555_06105385890905644_240.png',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 3,999',
#      'item_review': '(170)',
#      'rating': None,
#      'per_discount': '62% Off'},
#     {'product_name': "SWAVES Men's sports electronic waterproof watch with alarm,liesure, mount climbing funchion",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5798/2019/12/5798_06287022389327105_240.jpg',
#      'price': 'KSh 1,388',
#      'prev_price': 'KSh 2,338',
#      'item_review': '(17)',
#      'rating': None,
#      'per_discount': '40% Off'},
#     {'product_name': "Mens Fashion Casual Military Quartz Sports Wristwatch Full Steel  Men's Watches",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/6097/2020/06/6097_06461829899978972_240.jpg',
#      'price': 'KSh 595',
#      'prev_price': 'KSh 1,600',
#      'item_review': '(26)',
#      'rating': None,
#      'per_discount': '62% Off'},
#     {'product_name': '2Pcs/Set Couple Watches Fashion Watches Men Watches Women Watches Fashion Accessories',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1482/2019/08/1482_06184430296665199_240.jpg',
#      'price': 'KSh 459',
#      'prev_price': 'KSh 2,199',
#      'item_review': '(96)',
#      'rating': None,
#      'per_discount': '79% Off'},
#     {'product_name': 'Men Bling Bracelets+Luxury Full Diamonds Watch  Cuban Chain Gold Silver Men watch +Bracelet set',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2019/12/4807_06302371457188196_240.jpg',
#      'price': 'KSh 1,299',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(35)',
#      'rating': None,
#      'per_discount': '35% Off'},
#     {'product_name': 'CURREN 8301 Top Brand Luxury watch men date display Leather creative Quartz Wrist Watches brown one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2218/2018/11/2218_05966805045852660_240.jpg',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 3,200',
#      'item_review': '(149)',
#      'rating': None,
#      'per_discount': '53% Off'},
#     {'product_name': 'JC 2020 LED sports men women smartwatches LED bracelet fashion touch electronic gift watch',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5872/2020/04/5872_06391041963363483_240.jpg',
#      'price': 'KSh 186',
#      'prev_price': 'KSh 555',
#      'item_review': '(18)',
#      'rating': None,
#      'per_discount': '66% Off'},
#     {'product_name': "STSR Men's Stainless Steel Watch Men's Quartz Clock Men's Sports Watch Fashion Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5750/2019/09/5750_06229862591943796_240.jpg',
#      'price': 'KSh 479',
#      'prev_price': 'KSh 2,000',
#      'item_review': '(53)',
#      'rating': None,
#      'per_discount': '76% Off'},
#     {'product_name': 'WLISTH Brand Original Fashion Quartz Watch Alloy Double Calendar Waterproof Men Women Watch Brown Women',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2020/02/2247_06344769268233896_240.jpg',
#      'price': 'KSh 799',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(86)',
#      'rating': None,
#      'per_discount': '60% Off'},
#     {'product_name': "2020 Minimalist Men's Fashion Ultra Thin Watches Simple Men Business Stainless Steel Mesh Belt Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5422/2020/04/5422_06409694646778921_240.jpg',
#      'price': 'KSh 654',
#      'prev_price': 'KSh 2,099',
#      'item_review': '(19)',
#      'rating': None,
#      'per_discount': '68% Off'},
#     {'product_name': 'Men Hip Hop Gold Silver Luxury Bling  Full CZ Crystal Watch Cuba Sandblast Bracelet  Set',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06358130793297137_240.jpg',
#      'price': 'KSh 699',
#      'prev_price': 'KSh 1,699',
#      'item_review': '(15)',
#      'rating': None,
#      'per_discount': '58% Off'},
#     {'product_name': 'Men Women Couple Wrist Watch (not a pair) bracelet PU Leather Strap Round Dial Quartz Wristwatches',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5872/2020/01/5872_06322674366695011_240.jpg',
#      'price': 'KSh 198',
#      'prev_price': 'KSh 699',
#      'item_review': '(25)',
#      'rating': None,
#      'per_discount': '71% Off'},
#     {'product_name': 'Luxury Men Diamond Watch+Diamond Bracelet Luxury Fashion Gold Silver Men Ice Out Cuban Watch',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06359808533248554_240.jpg',
#      'price': 'KSh 1,299',
#      'prev_price': 'KSh 2,499',
#      'item_review': '(27)',
#      'rating': None,
#      'per_discount': '48% Off'}]},
#   {'page_3': [{'product_name': 'CUENA Men Watch leather straps Stainless Steel Good Quartz Luxury Man Wristwatch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/12/3281_06295448209529386_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(1151)',
#      'rating': None,
#      'per_discount': '90% Off'},
#     {'product_name': 'Men Watch Date Stainless Steel Male Watches Quartz WristWatch Wrist Watch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/08/3281_06198784598670487_240.jpg',
#      'price': 'KSh 690',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(268)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Men Watch Stainless Quartz WristWatch Waterproof Lady Lovers Women Male Date Classic Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/08/3281_06198840873745713_240.jpg',
#      'price': 'KSh 699',
#      'prev_price': 'KSh 4,000',
#      'item_review': '(249)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Genuine Curren Men Watches Fashion Sports Quartz Watches Leather Military Watch Gifts black 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440828496201102_240.jpg',
#      'price': 'KSh 450',
#      'prev_price': 'KSh 1,500',
#      'item_review': '(628)',
#      'rating': None,
#      'per_discount': '70% Off'},
#     {'product_name': "Men's Watch Quartz Men's Watch Blu-ray Glass Belt Watch Men's Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/04/5057_06099858887919745_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(296)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Genuine Men Watches Dial Military Quartz Leather Sport Watches Male Business Wristwatch black 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440830518573343_240.jpg',
#      'price': 'KSh 440',
#      'prev_price': 'KSh 1,599',
#      'item_review': '(469)',
#      'rating': None,
#      'per_discount': '72% Off'},
#     {'product_name': 'Yazole Leather Men Watch Man Luxury Quartz Stainless Steel Wrist Watches Wristwatch Valentine Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/11/3281_06275935451037089_240.png',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(186)',
#      'rating': None,
#      'per_discount': '86% Off'},
#     {'product_name': 'SKMEI Men Watches Sport Electronics Digital LED Quartz Watches Waterproof Alarm Watches Gifts black 25CM',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440740584138671_240.jpg',
#      'price': 'KSh 990',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(448)',
#      'rating': None,
#      'per_discount': '67% Off'},
#     {'product_name': 'Genuine Migeer Men Watches Leather Straps Stainless Steel Quartz Man Wristwatch Gifts brown 22cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/06/1213_06443213195115322_240.jpg',
#      'price': 'KSh 449',
#      'prev_price': 'KSh 1,500',
#      'item_review': '(529)',
#      'rating': None,
#      'per_discount': '70% Off'},
#     {'product_name': 'Luxury Men Watch Fashion Diamond Automatic Date Quartz Watch Men Gold Stainless Steel Hip Hop Watche',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06353739341067779_240.jpg',
#      'price': 'KSh 899',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(54)',
#      'rating': None,
#      'per_discount': '55% Off'},
#     {'product_name': 'Men Watches Fashion Casual Quartz Watch Geneva Fabric Nylon Canvas Military Watches Gifts 2 28cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/06/1213_06443213946897453_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(443)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Men Watches Stainless Steel Lady Watch Lovers Luxury Quartz Good Wristwatches Man Male Gift Women',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/3281/2019/07/3281_06174571743026090_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(122)',
#      'rating': None,
#      'per_discount': '86% Off'},
#     {'product_name': 'BOSCK Brand Original Mens Watch Stainless Steel Waterproof Men Quartz Watch Men Watch for Men Black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2018/03/2247_05754005615764969_240.jpg',
#      'price': 'KSh 599',
#      'prev_price': 'KSh 2,560',
#      'item_review': '(347)',
#      'rating': None,
#      'per_discount': '76% Off'},
#     {'product_name': '2020men watches Men Business Wristwatch Luxury Famous Male Clock Sports Quartz Watch Valentines Gift white brown one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/01/2223_05693730498201533_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 1,100',
#      'item_review': '(444)',
#      'rating': None,
#      'per_discount': '63% Off'},
#     {'product_name': 'Mens Watches Luxury Men Fashion Business Quartz watch clock Male WristWatches Valentines Gift black black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/02/2223_05731245282486211_240.jpg',
#      'price': 'KSh 369',
#      'prev_price': 'KSh 850',
#      'item_review': '(576)',
#      'rating': None,
#      'per_discount': '56% Off'},
#     {'product_name': "STSR New fashion watch men's watch luxury top brand casual sports quartz watch male clock",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5750/2019/09/5750_06229849127026454_240.jpg',
#      'price': 'KSh 179',
#      'prev_price': 'KSh 2,000',
#      'item_review': '(125)',
#      'rating': None,
#      'per_discount': '91% Off'},
#     {'product_name': "Fashion Gift Watch Quartz Watch Men's Colorful Blu-ray Glass Belt Men's Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5742/2019/11/5742_06261941948722181_240.jpg',
#      'price': 'KSh 199',
#      'prev_price': 'KSh 999',
#      'item_review': '(59)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': '2Pcs/Set Couple Watches Fashion Watches Men Watches Women Watches Fashion Accessories',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1482/2019/08/1482_06184431016347067_240.jpg',
#      'price': 'KSh 399',
#      'prev_price': 'KSh 2,099',
#      'item_review': '(68)',
#      'rating': None,
#      'per_discount': '80% Off'},
#     {'product_name': 'Men Watch leather strap Stainless Steel Good Quartz Luxury Business Man Wristwatch Valentines Gift',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2555/2019/08/2555_06203492826084739_240.png',
#      'price': 'KSh 429',
#      'prev_price': 'KSh 3,980',
#      'item_review': '(253)',
#      'rating': None,
#      'per_discount': '89% Off'},
#     {'product_name': 'Watch Men Top Brand Luxury Famous 2018 Wristwatch Male Clock Wrist Watch Business Quartz watch black black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2223/2018/03/2223_05742094787046585_240.jpg',
#      'price': 'KSh 369',
#      'prev_price': 'KSh 1,200',
#      'item_review': '(226)',
#      'rating': None,
#      'per_discount': '69% Off'},
#     {'product_name': "Men's Watch New ORLANDO Fashion Quartz Watch Men's Gold Plated Stainless Steel Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/07/5057_06153000410469662_240.jpg',
#      'price': 'KSh 479',
#      'prev_price': 'KSh 3,000',
#      'item_review': '(187)',
#      'rating': None,
#      'per_discount': '84% Off'},
#     {'product_name': "Fashion trend casual sports business men's watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5742/2020/06/5742_06443445122225261_240.jpg',
#      'price': 'KSh 239',
#      'prev_price': 'KSh 1,298',
#      'item_review': '(50)',
#      'rating': None,
#      'per_discount': '81% Off'},
#     {'product_name': 'SKMEI Men Watches Sports Electronic Military Stainless Steel PU Strap Watches Double Clock Gifts black 25cm',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1213/2020/05/1213_06440742361245664_240.jpg',
#      'price': 'KSh 1,199',
#      'prev_price': 'KSh 2,500',
#      'item_review': '(178)',
#      'rating': None,
#      'per_discount': '52% Off'},
#     {'product_name': "STSR 2020 Men's High Quality Quartz Luxury Men's Watch Gift Fashion Sports Leather Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5057/2019/10/5057_06254094190174553_240.jpg',
#      'price': 'KSh 179',
#      'prev_price': 'KSh 1,000',
#      'item_review': '(104)',
#      'rating': None,
#      'per_discount': '82% Off'},
#     {'product_name': 'Hip Hop Men Bracelets Gold Iced Out Crystal Miami Cuban Chain watch +Bracelet set Hip Hop King New',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2019/12/4807_06301869670278671_240.jpg',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 2,699',
#      'item_review': '(74)',
#      'rating': None,
#      'per_discount': '44% Off'},
#     {'product_name': 'NAVIFORCE Fashion Gold Men Sport Watch Mens LED Analog Digital Army Military Leather Quartz Watches',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2218/2019/09/2218_06215369650570981_240.jpg',
#      'price': 'KSh 1,999',
#      'prev_price': 'KSh 3,999',
#      'item_review': '(51)',
#      'rating': None,
#      'per_discount': '50% Off'},
#     {'product_name': 'BOSCK Brand Original Men Business Watch Double Calendar Waterproof Men Quartz Watch Men Watch black one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2018/01/2247_05689906772579379_240.jpg',
#      'price': 'KSh 799',
#      'prev_price': 'KSh 3,520',
#      'item_review': '(84)',
#      'rating': None,
#      'per_discount': '77% Off'},
#     {'product_name': 'LSVTR Brand 2 PCS Set Couples Wrist Watches Men Women Lovers Waterproof Quartz Wristwatches silver 2pcs (1 male and 1 female)',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2555/2019/05/2555_06105385890905644_240.png',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 3,999',
#      'item_review': '(170)',
#      'rating': None,
#      'per_discount': '62% Off'},
#     {'product_name': "SWAVES Men's sports electronic waterproof watch with alarm,liesure, mount climbing funchion",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5798/2019/12/5798_06287022389327105_240.jpg',
#      'price': 'KSh 1,388',
#      'prev_price': 'KSh 2,338',
#      'item_review': '(17)',
#      'rating': None,
#      'per_discount': '40% Off'},
#     {'product_name': "Mens Fashion Casual Military Quartz Sports Wristwatch Full Steel  Men's Watches",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/6097/2020/06/6097_06461829899978972_240.jpg',
#      'price': 'KSh 595',
#      'prev_price': 'KSh 1,600',
#      'item_review': '(26)',
#      'rating': None,
#      'per_discount': '62% Off'},
#     {'product_name': '2Pcs/Set Couple Watches Fashion Watches Men Watches Women Watches Fashion Accessories',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/1482/2019/08/1482_06184430296665199_240.jpg',
#      'price': 'KSh 459',
#      'prev_price': 'KSh 2,199',
#      'item_review': '(96)',
#      'rating': None,
#      'per_discount': '79% Off'},
#     {'product_name': 'Men Bling Bracelets+Luxury Full Diamonds Watch  Cuban Chain Gold Silver Men watch +Bracelet set',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2019/12/4807_06302371457188196_240.jpg',
#      'price': 'KSh 1,299',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(35)',
#      'rating': None,
#      'per_discount': '35% Off'},
#     {'product_name': 'CURREN 8301 Top Brand Luxury watch men date display Leather creative Quartz Wrist Watches brown one size',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2218/2018/11/2218_05966805045852660_240.jpg',
#      'price': 'KSh 1,499',
#      'prev_price': 'KSh 3,200',
#      'item_review': '(149)',
#      'rating': None,
#      'per_discount': '53% Off'},
#     {'product_name': 'JC 2020 LED sports men women smartwatches LED bracelet fashion touch electronic gift watch',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5872/2020/04/5872_06391041963363483_240.jpg',
#      'price': 'KSh 186',
#      'prev_price': 'KSh 555',
#      'item_review': '(18)',
#      'rating': None,
#      'per_discount': '66% Off'},
#     {'product_name': "STSR Men's Stainless Steel Watch Men's Quartz Clock Men's Sports Watch Fashion Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5750/2019/09/5750_06229862591943796_240.jpg',
#      'price': 'KSh 479',
#      'prev_price': 'KSh 2,000',
#      'item_review': '(53)',
#      'rating': None,
#      'per_discount': '76% Off'},
#     {'product_name': 'WLISTH Brand Original Fashion Quartz Watch Alloy Double Calendar Waterproof Men Women Watch Brown Women',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/2247/2020/02/2247_06344769268233896_240.jpg',
#      'price': 'KSh 799',
#      'prev_price': 'KSh 1,999',
#      'item_review': '(86)',
#      'rating': None,
#      'per_discount': '60% Off'},
#     {'product_name': "2020 Minimalist Men's Fashion Ultra Thin Watches Simple Men Business Stainless Steel Mesh Belt Watch",
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5422/2020/04/5422_06409694646778921_240.jpg',
#      'price': 'KSh 654',
#      'prev_price': 'KSh 2,099',
#      'item_review': '(19)',
#      'rating': None,
#      'per_discount': '68% Off'},
#     {'product_name': 'Men Hip Hop Gold Silver Luxury Bling  Full CZ Crystal Watch Cuba Sandblast Bracelet  Set',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06358130793297137_240.jpg',
#      'price': 'KSh 699',
#      'prev_price': 'KSh 1,699',
#      'item_review': '(15)',
#      'rating': None,
#      'per_discount': '58% Off'},
#     {'product_name': 'Men Women Couple Wrist Watch (not a pair) bracelet PU Leather Strap Round Dial Quartz Wristwatches',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/5872/2020/01/5872_06322674366695011_240.jpg',
#      'price': 'KSh 198',
#      'prev_price': 'KSh 699',
#      'item_review': '(25)',
#      'rating': None,
#      'per_discount': '71% Off'},
#     {'product_name': 'Luxury Men Diamond Watch+Diamond Bracelet Luxury Fashion Gold Silver Men Ice Out Cuban Watch',
#      'item_link': 'https://www.kilimall.co.ke/',
#      'image_src': 'https://image.kilimall.com/kenya/shop/store/goods/4807/2020/02/4807_06359808533248554_240.jpg',
#      'price': 'KSh 1,299',
#      'prev_price': 'KSh 2,499',
#      'item_review': '(27)',
#      'rating': None,
#      'per_discount': '48% Off'}]}]}
